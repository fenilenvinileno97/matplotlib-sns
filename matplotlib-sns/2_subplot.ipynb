# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1, 10, 11)
y = x**2

# %%
k = np.linspace(-4*np.pi, 4*np.pi, num=100)
z = np.sin(1.5*k)
m = np.tan(k)

# %% [markdown]
# #### Subplot
# Creates stacked graphs, adding up rows or columns, each with different data. `.subplot()` method creates m*n stacked chart, as it'd be a matrix, we can access to each through index.
#
# ``plt.subplot(nrows = 1, ncols = 2, index= 1)`` #This creates two subplots in the same figure, with one row and two columns
#
# This statement can be also written or expressed in a more compact way:
#
# ``plt.subplot(1,2,1)``, or ``plt.subplot(121)``.
#
# When we point the index, we can modify the content inside that layer, as it seen in the code block below.

# %%
plt.subplot(1,2,1)
plt.hist(y, color='#803763')
plt.subplot(1,2,2)
plt.plot(k, z, 'g--')
plt.plot(k, m, 'b-.')
plt.show()

# %%
plt.subplot(2,1,1)
plt.hist(y, color='black')
plt.subplot(2,1,2)
plt.plot(k, z, 'g--')
plt.plot(k, m, 'b-.')  
plt.show()

# %%
# Generate some data
x = np.linspace(0, 2*np.pi, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# Create a figure and add subplots
fig = plt.figure()

# Add the first subplot
ax1 = fig.add_subplot(2, 1, 1)
ax1.plot(x, y1)
ax1.set_title('Sine')

# Add the second subplot
ax2 = fig.add_subplot(2, 1, 2)
ax2.plot(x, y2)
ax2.set_title('Cosine')

# Adjust the layout
plt.tight_layout()

# Display the figure
plt.show()
